# %%
# !find /Users/colelacroix/math -name "*.ipynb" -not -path "*/.ipynb_checkpoints/*" -not -path "*/_build/*"
# Out:
# /Users/colelacroix/math/0.1_think_bayes_(Downey)/1_probability.ipynb
# /Users/colelacroix/math/inventory/siuslaw_camera_placement.ipynb
# /Users/colelacroix/math/inventory/bayes_timber.ipynb
# /Users/colelacroix/math/quick_access.ipynb

# %%
config = '''# See docs at: https://mystmd.org/guide/frontmatter
version: 1
project:
  id: af601852-cbc3-4d41-9731-bb9a87aa495e
  title: "Math Notes"
  description: "Notes and worked examples"
  github: https://github.com/coletlacroix/math
  toc:
    - title: Think Bayes (Downey)
      children:
        - file: 0.1_think_bayes_(Downey)/1_probability.ipynb
site:
  template: book-theme
'''

with open("/Users/colelacroix/math/myst.yml", "w") as f:
    f.write(config)

print("myst.yml rewritten")
# Out:
# myst.yml rewritten

# %%
# !jupyter book start
# Out:
# building myst-cli session with API URL: https://api.mystmd.org
# (node:26181) ExperimentalWarning: localStorage is not available because --localstorage-file was not provided.
# (Use `node --trace-warnings ...` to show where the warning was created)
# First TOC item must be a file
#
#
# Myst CLI Versions:
#  - node                         26.7.0     Required: >= 18.0.0
#  - npm                         11.19.0     Required: >=8.6.0
#  - myst                         1.10.1

# %%
import os
os.chdir("/Users/colelacroix/math")
print(os.getcwd())
# Out:
# /Users/colelacroix/math

# %%
import sys
# !{sys.executable} -m pip install -U jupyter-book
# Out:
# Requirement already satisfied: jupyter-book in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.1.6)
# Requirement already satisfied: ipykernel in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jupyter-book) (6.30.1)
# Requirement already satisfied: jupyter-core in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jupyter-book) (5.8.1)
# Requirement already satisfied: jupyter-server in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jupyter-book) (2.17.0)
# Requirement already satisfied: platformdirs>=4.2.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jupyter-book) (4.4.0)
# Requirement already satisfied: nodeenv>=1.9.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jupyter-book) (1.10.0)
# Requirement already satisfied: appnope>=0.1.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ipykernel->jupyter-book) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ipykernel->jupyter-book) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ipykernel->jupyter-book) (1.8.16)
# Requirement already satisfied: ipython>=7.23.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ipykernel->jupyter-book) (9.4.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ipykernel->jupyter-book) (8.6.3)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ipykernel->jupyter-book) (0.1.7)
# Requirement already satisfied: nest-asyncio>=1.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ipykernel->jupyter-book) (1.6.0)
# Requirement already satisfied: packaging>=22 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ipykernel->jupyter-book) (25.0)
# Requirement already satisfied: psutil>=5.7 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ipykernel->jupyter-book) (7.0.0)
# Requirement already satisfied: pyzmq>=25 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ipykernel->jupyter-book) (27.0.2)
# Requirement already satisfied: tornado>=6.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ipykernel->jupyter-book) (6.5.2)
# Requirement already satisfied: traitlets>=5.4.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ipykernel->jupyter-book) (5.14.3)
# Requirement already satisfied: decorator in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->jupyter-book) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->jupyter-book) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->jupyter-book) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->jupyter-book) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->jupyter-book) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->jupyter-book) (2.19.2)
# Requirement already satisfied: stack_data in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->jupyter-book) (0.6.3)
# Requirement already satisfied: wcwidth in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyter-book) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter-book) (0.8.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jupyter-client>=8.0.0->ipykernel->jupyter-book) (2.9.0.post0)
# Requirement already satisfied: ptyprocess>=0.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter-book) (0.7.0)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.0.0->ipykernel->jupyter-book) (1.17.0)
# Requirement already satisfied: anyio>=3.1.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jupyter-server->jupyter-book) (4.10.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jupyter-server->jupyter-book) (25.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jupyter-server->jupyter-book) (3.1.6)
# Requirement already satisfied: jupyter-events>=0.11.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jupyter-server->jupyter-book) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jupyter-server->jupyter-book) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jupyter-server->jupyter-book) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jupyter-server->jupyter-book) (5.10.4)
# Requirement already satisfied: prometheus-client>=0.9 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jupyter-server->jupyter-book) (0.22.1)
# Requirement already satisfied: send2trash>=1.8.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jupyter-server->jupyter-book) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jupyter-server->jupyter-book) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jupyter-server->jupyter-book) (1.8.0)
# Requirement already satisfied: idna>=2.8 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from anyio>=3.1.0->jupyter-server->jupyter-book) (3.11)
# Requirement already satisfied: sniffio>=1.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from anyio>=3.1.0->jupyter-server->jupyter-book) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from argon2-cffi>=21.1->jupyter-server->jupyter-book) (25.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jinja2>=3.0.3->jupyter-server->jupyter-book) (3.0.3)
# Requirement already satisfied: jsonschema>=4.18.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter-book) (4.25.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server->jupyter-book) (3.3.0)
# Requirement already satisfied: pyyaml>=5.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server->jupyter-book) (6.0.2)
# Requirement already satisfied: referencing in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server->jupyter-book) (0.36.2)
# Requirement already satisfied: rfc3339-validator in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server->jupyter-book) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server->jupyter-book) (0.1.1)
# Requirement already satisfied: attrs>=22.2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter-book) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter-book) (2025.4.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter-book) (0.27.1)
# Requirement already satisfied: fqdn in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter-book) (1.5.1)
# Requirement already satisfied: isoduration in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter-book) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter-book) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter-book) (1.1.0)
# Requirement already satisfied: uri-template in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter-book) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter-book) (24.11.1)
# Requirement already satisfied: beautifulsoup4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from nbconvert>=6.4.4->jupyter-server->jupyter-book) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server->jupyter-book) (6.2.0)
# Requirement already satisfied: defusedxml in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from nbconvert>=6.4.4->jupyter-server->jupyter-book) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from nbconvert>=6.4.4->jupyter-server->jupyter-book) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from nbconvert>=6.4.4->jupyter-server->jupyter-book) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from nbconvert>=6.4.4->jupyter-server->jupyter-book) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from nbconvert>=6.4.4->jupyter-server->jupyter-book) (1.5.1)
# Requirement already satisfied: webencodings in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server->jupyter-book) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server->jupyter-book) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from nbformat>=5.3.0->jupyter-server->jupyter-book) (2.21.2)
# Requirement already satisfied: lark>=1.2.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter-book) (1.2.2)
# Requirement already satisfied: cffi>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server->jupyter-book) (2.1.0)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server->jupyter-book) (2.22)
# Requirement already satisfied: soupsieve>1.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server->jupyter-book) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server->jupyter-book) (4.15.0)
# Requirement already satisfied: arrow>=0.15.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter-book) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter-book) (2.9.0.20250822)
# Requirement already satisfied: executing>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter-book) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter-book) (3.0.0)
# Requirement already satisfied: pure-eval in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter-book) (0.2.3)
#
# [notice] A new release of pip is available: 25.2 -> 26.2
# [notice] To update, run: pip3 install --upgrade pip

# %%
config = '''# See docs at: https://mystmd.org/guide/frontmatter
version: 1
project:
  id: af601852-cbc3-4d41-9731-bb9a87aa495e
  title: "Math Notes"
  description: "Notes and worked examples"
  github: https://github.com/coletlacroix/math
  toc:
    - title: Think Bayes (Downey)
      children:
        - file: 0.1_think_bayes_(Downey)/1_probability.ipynb
site:
  template: book-theme
'''

with open("myst.yml", "w") as f:
    f.write(config)

print("myst.yml written")
# Out:
# myst.yml written

# %%
# !cat myst.yml
# Out:
# # See docs at: https://mystmd.org/guide/frontmatter
# version: 1
# project:
#   id: af601852-cbc3-4d41-9731-bb9a87aa495e
#   title: "Math Notes"
#   description: "Notes and worked examples"
#   github: https://github.com/coletlacroix/math
#   toc:
#     - title: Think Bayes (Downey)
#       children:
#         - file: 0.1_think_bayes_(Downey)/1_probability.ipynb
# site:
#   template: book-theme

# %%
index_content = """# Math Notes

Welcome to my collection of math notes and worked examples.
"""

with open("index.md", "w") as f:
    f.write(index_content)

print("index.md created")
# Out:
# index.md created

# %%
config = '''# See docs at: https://mystmd.org/guide/frontmatter
version: 1
project:
  id: af601852-cbc3-4d41-9731-bb9a87aa495e
  title: "Math Notes"
  description: "Notes and worked examples"
  github: https://github.com/coletlacroix/math
  toc:
    - file: index.md
    - title: Think Bayes (Downey)
      children:
        - file: 0.1_think_bayes_(Downey)/1_probability.ipynb
site:
  template: book-theme
'''

with open("myst.yml", "w") as f:
    f.write(config)

print("myst.yml rewritten")
# Out:
# myst.yml rewritten

# %%
# !jupyter book start
# Out:
# building myst-cli session with API URL: https://api.mystmd.org
# (node:26403) ExperimentalWarning: localStorage is not available because --localstorage-file was not provided.
# (Use `node --trace-warnings ...` to show where the warning was created)
# 📖 Built index.md in 51 ms.
# ⚠️  0.1_think_bayes_(Downey)/1_probability.ipynb missing heading depth 3
# 📖 Built 0.1_think_bayes_(Downey)/1_probability.ipynb in 42 ms.
# 📚 Built 2 pages for project in 107 ms.
#
#
# 	✨✨✨  Starting Book Theme  ✨✨✨
#
#
#
# 🔌 Server started on port 3000!  🥳 🎉
#
#
# 	👉  http://localhost:3000  👈
#
#
# (node:26431) [DEP0169] DeprecationWarning: `url.parse()` behavior is not standardized and prone to errors that have security implications. Use the WHATWG URL API instead. CVEs are not issued for `url.parse()` vulnerabilities.
#
# 💌 GET  / 200 - - 44.116 ms
# 💌 GET  /myst-theme.css 200 - - 24.472 ms
# 💌 GET  /favicon.ico 200 - - 257.559 ms
# 💌 GET  /probability?_data=routes%2F%24 200 - - 17.447 ms
# 💌 GET  /probability?_data=routes%2F%24 200 - - 16.272 ms
# ⚠️ File is not in project: quick_access.ipynb
# 💌 GET  /?_data=routes%2F_index 200 - - 35.811 ms
# 💌 GET  /?_data=routes%2F_index 200 - - 9.805 ms
# 💌 GET  /probability?_data=routes%2F%24 200 - - 35.785 ms
# 💌 GET  /probability?_data=routes%2F%24 200 - - 14.985 ms
# 💌 GET  /probability?_data=routes%2F%24 200 - - 18.317 ms

# %%
# !jupyter book init --gh-pages
# Out:
# building myst-cli session with API URL: https://api.mystmd.org
# (node:26285) ExperimentalWarning: localStorage is not available because --localstorage-file was not provided.
# (Use `node --trace-warnings ...` to show where the warning was created)
# 📝 Creating a GitHub Action to deploy your MyST Site
#
# ? What branch would you like to deploy from? (main)

# %%
# !git add .
# !git commit -m "Add index page to fix TOC build error"
# !git push origin main
