# %%
pip install -U jupyter-book
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 17.7 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [jupyter-book]
# ...
#
# [notice] A new release of pip is available: 25.2 -> 26.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
config = """version: 1
project:
  title: "math"
  description: "Notes and worked examples"
site:
  template: book-theme
"""

with open("myst.yml", "w") as f:
    f.write(config)

print("myst.yml created")
# Out:
# myst.yml created

# %%
# !jupyter book init --write-toc
# Out:
# building myst-cli session with API URL: https://api.mystmd.org
# (node:22906) ExperimentalWarning: localStorage is not available because --localstorage-file was not provided.
# (Use `node --trace-warnings ...` to show where the warning was created)
# 💾 Writing default .gitignore
# ✅ Project already initialized with config file: myst.yml
# ✅ Site already initialized with config file: myst.yml
# 💾 Writing new TOC to: myst.yml

# %%
# !jupyter book start
# Out:
# building myst-cli session with API URL: https://api.mystmd.org
# (node:22964) ExperimentalWarning: localStorage is not available because --localstorage-file was not provided.
# (Use `node --trace-warnings ...` to show where the warning was created)
# 🔍 Querying template metadata from https://api.mystmd.org/templates/site/myst/book-theme
# 🐕 Fetching template from https://github.com/myst-templates/book-theme/archive/refs/heads/main.zip
# 💾 Saved template to path _build/templates/site/myst/book-theme
# ⤵️  Installing web libraries (can take up to 60 s)
# npm notice
# npm notice New major version of npm available! 11.19.0 -> 12.0.2
# npm notice Changelog: https://github.com/npm/cli/releases/tag/v12.0.2
# npm notice To update run: npm install -g npm@12.0.2
# npm notice
#
# 📦 Installed web libraries in 1.69 s
# ⚠️  1_probability.ipynb missing heading depth 3
# 📖 Built 1_probability.ipynb in 18 ms.
# 📖 Built Untitled.ipynb in 17 ms.
# 📚 Built 2 pages for project in 55 ms.
#
#
# ...

# %%
# !jupyter book init --gh-pages
# Out:
# building myst-cli session with API URL: https://api.mystmd.org
# (node:25024) ExperimentalWarning: localStorage is not available because --localstorage-file was not provided.
# (Use `node --trace-warnings ...` to show where the warning was created)
# Please Run From Root
#
# Please run this command from the root of the git repository.

# %%
# !git add .
# !git commit -m "Set up Jupyter Book"
# !git push origin main
# Out:
# [main af843f9] Set up Jupyter Book
#  4 files changed, 889 insertions(+), 8 deletions(-)
#  create mode 100644 0.1_think_bayes_(Downey)/.gitignore
#  create mode 100644 0.1_think_bayes_(Downey)/.ipynb_checkpoints/1_probability-checkpoint.ipynb
#  create mode 100644 0.1_think_bayes_(Downey)/myst.yml
# Enumerating objects: 9, done.
# Counting objects: 100% (9/9), done.
# Delta compression using up to 8 threads
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (7/7), 4.36 KiB | 4.36 MiB/s, done.
# Total 7 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# To https://github.com/coletlacroix/math.git
#    8b50806..af843f9  main -> main

# %%
# !ls -la .github/workflows/
# Out:
# ls: .github/workflows/: No such file or directory

# %%
# !pwd
# !ls -la
# Out:
# /Users/colelacroix/math/0.1_think_bayes_(Downey)
# total 56
# drwxr-xr-x  4 colelacroix  staff    128 Aug  7 18:48 _build
# drwxr-xr-x  7 colelacroix  staff    224 Aug  7 18:56 .
# drwxr-xr-x  9 colelacroix  staff    288 Aug  7 19:00 ..
# -rw-r--r--  1 colelacroix  staff     28 Aug  7 18:48 .gitignore
# drwxr-xr-x  3 colelacroix  staff     96 Aug  7 18:56 .ipynb_checkpoints
# -rw-r--r--  1 colelacroix  staff  18597 Aug  7 16:23 1_probability.ipynb
# -rw-r--r--  1 colelacroix  staff    227 Aug  7 18:48 myst.yml

# %%
# !cd..
# Out:
# /bin/bash: cd..: command not found

# %%
# !mv "0.1_think_bayes_(Downey)/myst.yml" myst.yml
# Out:
# mv: rename 0.1_think_bayes_(Downey)/myst.yml to myst.yml: No such file or directory

# %%
# !pwd
# Out:
# /Users/colelacroix/math/0.1_think_bayes_(Downey)

# %%
# !mv myst.yml ../myst.yml
# Out:
# mv: myst.yml: No such file or directory

# %%
# !ls /Users/colelacroix/math
# Out:
# 0.1_think_bayes_(Downey)    myst.yml
# 1. Algebra and Trigonometry quick_access.ipynb
# inventory

# %%
# !git -C /Users/colelacroix/math rev-parse --show-toplevel
# Out:
# /Users/colelacroix/math

# %%
# !jupyter book init --write-toc
# Out:
# building myst-cli session with API URL: https://api.mystmd.org
# (node:25810) ExperimentalWarning: localStorage is not available because --localstorage-file was not provided.
# (Use `node --trace-warnings ...` to show where the warning was created)
# 💾 Writing new project and site config file: myst.yml
# 💾 Writing new TOC to: myst.yml

# %%
# !cat myst.yml
# Out:
# # See docs at: https://mystmd.org/guide/frontmatter
# version: 1
# project:
#   id: af601852-cbc3-4d41-9731-bb9a87aa495e
#   # title:
#   # description:
#   # keywords: []
#   # authors: []
#   github: https://github.com/coletlacroix/math
#   # To autogenerate a Table of Contents, run "jupyter book init --write-toc"
#   toc:
#     # Auto-generated by `myst init --write-toc`
#     - file: 1_probability.ipynb
#
# site:
#   template: book-theme
#   # options:
#   #   favicon: favicon.ico
#   #   logo: site_logo.png

# %%
# !pwd
# Out:
# /Users/colelacroix/math/0.1_think_bayes_(Downey)

# %%
# !find . -name "*.ipynb" -not -path "*/.ipynb_checkpoints/*" -not -path "*/_build/*"
# Out:
# ./1_probability.ipynb

# %%
# !pwd
# Out:
# /Users/colelacroix/math/0.1_think_bayes_(Downey)
