# %% [markdown]
# # Bayes's Theorem

# %%
# !find "0.1_think_bayes_(Downey)" -name "*.ipynb"
# Out:
# 0.1_think_bayes_(Downey)/2_bayes's_theorem.ipynb
# 0.1_think_bayes_(Downey)/_build/site/public/Untitled-698782dc1030227a3da13d71e088bda4.ipynb
# 0.1_think_bayes_(Downey)/_build/site/public/Untitled-d274fd845b690db4b7be1bc709ced415.ipynb
# 0.1_think_bayes_(Downey)/_build/site/public/1_probability-651e306e80756e6741ea4f98929b5957.ipynb
# 0.1_think_bayes_(Downey)/.ipynb_checkpoints/1_probability-checkpoint.ipynb
# 0.1_think_bayes_(Downey)/.ipynb_checkpoints/2_bayes's_theorem-checkpoint.ipynb
# 0.1_think_bayes_(Downey)/1_probability.ipynb
